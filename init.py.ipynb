# %%
# !ls
# Out:
# README.md     df.csv        final         init.py.ipynb test.py

# %%
import os

# %%
dirs = os.listdir('final')

# %%
dirs
# Out:
# ['komal oli',
#  'Giriraj Mani Pokharel',
#  'Onsari Gharti Magar',
#  'Prabhu Sah',
#  'Surendra Pandey',
#  'Rekha Thapa',
#  'nabina lama',
#  'prachanda',
#  'Madhav Kumar Nepal',
#  'Shashanka Koirala',
#  'Minendra Rijal',
#  'Mahindra Ray Yadav',
#  'Sunita Dangol',
#  'rabindra adhikari',
#  'Prithvi Man Gurung',
#  'Raghubir Mahaseth',
#  'Bijay Kumar Gachhadar',
#  'Lokendra Bahadur Chand',
#  '.DS_Store',
#  'Baburam Bhattarai',
#  'Shishir Khanal',
#  'Kalpana Bista',
#  'Chitra Bahadur K.C.',
#  'Ghanashyam Bhusal',
#  'Binod Chaudhary',
#  'C. P. Mainali',
#  'Kunti devi Pokhrel',
#  'Balen Shah',
#  'Nanda Kishor Pun',
#  'Pampha Bhusal',
#  'Dhana Raj Acharya',
#  'Prem Ale',
#  'sunita baral',
#  'Shankar Pokharel',
#  'Mahesh Basnet',
#  'Sobita Gautam',
#  'Subaschandra Nemwang',
#  'Renu Dahal',
#  'Ram Kumari Jhakri',
#  'Arzu Rana Deuba',
#  'Bimalendra Nidhi',
#  'Ram Baran Yadav',
#  'Swarnim Wagle',
#  'Jhala Nath Khanal',
#  'Gokul Prasad Baskota',
# ...

# %%
import pandas as pd

# %%
dirs.remove('.DS_Store')

# %%
dirs
# Out:
# ['komal oli',
#  'Giriraj Mani Pokharel',
#  'Onsari Gharti Magar',
#  'Prabhu Sah',
#  'Surendra Pandey',
#  'Rekha Thapa',
#  'nabina lama',
#  'prachanda',
#  'Madhav Kumar Nepal',
#  'Shashanka Koirala',
#  'Minendra Rijal',
#  'Mahindra Ray Yadav',
#  'Sunita Dangol',
#  'rabindra adhikari',
#  'Prithvi Man Gurung',
#  'Raghubir Mahaseth',
#  'Bijay Kumar Gachhadar',
#  'Lokendra Bahadur Chand',
#  'Baburam Bhattarai',
#  'Shishir Khanal',
#  'Kalpana Bista',
#  'Chitra Bahadur K.C.',
#  'Ghanashyam Bhusal',
#  'Binod Chaudhary',
#  'C. P. Mainali',
#  'Kunti devi Pokhrel',
#  'Balen Shah',
#  'Nanda Kishor Pun',
#  'Pampha Bhusal',
#  'Dhana Raj Acharya',
#  'Prem Ale',
#  'sunita baral',
#  'Shankar Pokharel',
#  'Mahesh Basnet',
#  'Sobita Gautam',
#  'Subaschandra Nemwang',
#  'Renu Dahal',
#  'Ram Kumari Jhakri',
#  'Arzu Rana Deuba',
#  'Bimalendra Nidhi',
#  'Ram Baran Yadav',
#  'Swarnim Wagle',
#  'Jhala Nath Khanal',
#  'Gokul Prasad Baskota',
# ...

# %%
df = pd.DataFrame(dirs,columns=['Politicians'])

# %%
df.to_csv('df.csv')

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#      Unnamed: 0            Politicians     Sex  DOB  Political Party  \
# 0             0              komal oli  Female  NaN              NaN
# 1             1  Giriraj Mani Pokharel    Male  NaN              NaN
# 2             2    Onsari Gharti Magar  Female  NaN              NaN
# 3             3             Prabhu Sah    Male  NaN              NaN
# 4             4        Surendra Pandey    Male  NaN              NaN
# ..          ...                    ...     ...  ...              ...
# 102         102           Barsaman Pun     NaN  NaN              NaN
# 103         103     Ram Chandra Poudel     NaN  NaN              NaN
# 104         104       Rupchandra Bista     NaN  NaN              NaN
# 105         105            Hisila Yami     NaN  NaN              NaN
# 106         106         Deepak Manange     NaN  NaN              NaN
#
#      Area of Represenation
# 0                      NaN
# 1                      NaN
# 2                      NaN
# ...
